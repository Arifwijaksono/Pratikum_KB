# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ***Membuat Box Plot dengan Visualisasi Negara Produksi Film dan Acara TV Terbanyak***

# %%
# Membaca data dari CSV
df = pd.read_csv('netflix_titles.csv')

plt.figure(figsize=(12, 6))
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title('Negara Produksi Terbanyak di Netflix')
plt.xlabel('Negara')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Membuat grafik pie chart berdasarkan tahun film dan acara TV di Netflix***

# %%
plt.figure(figsize=(8, 8))
year_counts = df['release_year'].value_counts().head(10)  # Ambil 10 tahun teratas
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Persentase Film dan Acara TV di Netflix Berdasarkan Tahun')
plt.axis('equal')  # Untuk memastikan pie chart berbentuk lingkaran
plt.show()

# %% [markdown]
# ***Mengubah kolom 'duration' menjadi tipe data numerik (menghilangkan ' min' dari setiap entri)
# Membuat Box Plot untuk durasi film***

# %%
df.dropna(subset=['duration'], inplace=True)

df['duration'] = df['duration'].str.extract('(\d+)').astype(int)

# Membuat Box Plot untuk durasi film
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='duration')
plt.title('Distribusi Durasi Film di Netflix')
plt.ylabel('Durasi (menit)')
plt.show()

# %% [markdown]
# ***Membuat Grafik Heatmap untuk menghitung matriks korelasi fitur Numerik dalam dataset Netflix***

# %%
correlation = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi antar Kolom dalam Dataset Netflix')
plt.show()
