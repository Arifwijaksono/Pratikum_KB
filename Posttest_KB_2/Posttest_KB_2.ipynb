# %%
import pandas as pd

# %% [markdown]
# ***1.Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum***

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
pd.DataFrame(data)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year  rating   duration  \
# 0     September 25, 2021          2020     NaN     90 min
# 1     September 24, 2021          2021     NaN  2 Seasons
# 2     September 24, 2021          2021     NaN   1 Season
# 3     September 24, 2021          2021     NaN   1 Season
# 4     September 24, 2021          2021     NaN  2 Seasons
# ...                  ...           ...     ...        ...
# 8802   November 20, 2019          2007     NaN    158 min
# 8803        July 1, 2019          2018     NaN  2 Seasons
# 8804    November 1, 2019          2009     NaN     88 min
# 8805    January 11, 2020          2006     NaN     88 min
# 8806       March 2, 2019          2015     NaN    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# ***Menampilkan Target Rating***

# %%
data.describe()
# Out:
#        release_year  rating
# count   8807.000000     0.0
# mean    2014.180198     NaN
# std        8.819312     NaN
# min     1925.000000     NaN
# 25%     2013.000000     NaN
# 50%     2017.000000     NaN
# 75%     2019.000000     NaN
# max     2021.000000     NaN

# %% [markdown]
# ***2.Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.***

# %%
AtributAngka = data.select_dtypes(include=['int64', 'float64'])
AtributAngka.head(10)
# Out:
#    release_year  rating
# 0          2020     NaN
# 1          2021     NaN
# 2          2021     NaN
# 3          2021     NaN
# 4          2021     NaN
# 5          2021     NaN
# 6          2021     NaN
# 7          1993     NaN
# 8          2021     NaN
# 9          2021     NaN

# %% [markdown]
# ***3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.***

# %% [markdown]
# info = {}
# info['Jumlah record'] = len(data)
# info['Jumlah Atrribute'] = data.shape[1]
# info['Nama Atributte'] = data.columns
# info['Jumlah Atrribute bertipe angka'] = data.select_dtypes(include=['int', 'float']).shape[1]
# pd.DataFrame.from_dict(info)

# %% [markdown]
# ***4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.***

# %%
data.loc[129:,'type':]
# Out:
#          type                        title               director  \
# 129     Movie           An Unfinished Life        Lasse Hallström
# 130     Movie   Barbie Big City Big Dreams  Scott Pleydell-Pearce
# 131     Movie  Blade Runner: The Final Cut           Ridley Scott
# 132   TV Show        Brave Animated Series                    NaN
# 133     Movie                      Chappie         Neill Blomkamp
# ...       ...                          ...                    ...
# 8802    Movie                       Zodiac          David Fincher
# 8803  TV Show                  Zombie Dumb                    NaN
# 8804    Movie                   Zombieland        Ruben Fleischer
# 8805    Movie                         Zoom           Peter Hewitt
# 8806    Movie                       Zubaan            Mozez Singh
#
#                                                    cast  \
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# 130   America Young, Amber May, Giselle Fernandez, A...
# 131   Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 132   Tseng Yun-fan, Kao Yun-shuo, Chiang Ching-yen,...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...                                                 ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                           country         date_added  release_year  rating  \
# 129        Germany, United States  September 1, 2021          2005     NaN
# 130                           NaN  September 1, 2021          2021     NaN
# 131                 United States  September 1, 2021          1982     NaN
# 132                           NaN  September 1, 2021          2021     NaN
# 133   South Africa, United States  September 1, 2021          2015     NaN
# ...                           ...                ...           ...     ...
# 8802                United States  November 20, 2019          2007     NaN
# 8803                          NaN       July 1, 2019          2018     NaN
# 8804                United States   November 1, 2019          2009     NaN
# 8805                United States   January 11, 2020          2006     NaN
# 8806                        India      March 2, 2019          2015     NaN
#
#        duration                                          listed_in  \
# 129     108 min                                             Dramas
# 130      63 min         Children & Family Movies, Music & Musicals
# 131     117 min    Action & Adventure, Classic Movies, Cult Movies
# 132    1 Season  International TV Shows, TV Action & Adventure,...
# 133     121 min               Action & Adventure, Sci-Fi & Fantasy
# ...         ...                                                ...
# 8802    158 min                     Cult Movies, Dramas, Thrillers
# 8803  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
# 8804     88 min                            Comedies, Horror Movies
# 8805     88 min                 Children & Family Movies, Comedies
# 8806    111 min     Dramas, International Movies, Music & Musicals
#
#                                             description
# 129   A grieving widow and her daughter move in with...
# 130   At a summer performing arts program in New Yor...
# 131   In a smog-choked dystopian Los Angeles, blade ...
# 132   A group of superheroes sets out to rid the wor...
# 133   In a futuristic society where an indestructibl...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8678 rows x 11 columns]

# %% [markdown]
# ***4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.***

# %%
data.iloc[129:,4:]
# Out:
#                                                    cast  \
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# 130   America Young, Amber May, Giselle Fernandez, A...
# 131   Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 132   Tseng Yun-fan, Kao Yun-shuo, Chiang Ching-yen,...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...                                                 ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                           country         date_added  release_year  rating  \
# 129        Germany, United States  September 1, 2021          2005     NaN
# 130                           NaN  September 1, 2021          2021     NaN
# 131                 United States  September 1, 2021          1982     NaN
# 132                           NaN  September 1, 2021          2021     NaN
# 133   South Africa, United States  September 1, 2021          2015     NaN
# ...                           ...                ...           ...     ...
# 8802                United States  November 20, 2019          2007     NaN
# 8803                          NaN       July 1, 2019          2018     NaN
# 8804                United States   November 1, 2019          2009     NaN
# 8805                United States   January 11, 2020          2006     NaN
# 8806                        India      March 2, 2019          2015     NaN
#
#        duration                                          listed_in  \
# 129     108 min                                             Dramas
# 130      63 min         Children & Family Movies, Music & Musicals
# 131     117 min    Action & Adventure, Classic Movies, Cult Movies
# 132    1 Season  International TV Shows, TV Action & Adventure,...
# 133     121 min               Action & Adventure, Sci-Fi & Fantasy
# ...         ...                                                ...
# 8802    158 min                     Cult Movies, Dramas, Thrillers
# 8803  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
# 8804     88 min                            Comedies, Horror Movies
# 8805     88 min                 Children & Family Movies, Comedies
# 8806    111 min     Dramas, International Movies, Music & Musicals
#
#                                             description
# 129   A grieving widow and her daughter move in with...
# 130   At a summer performing arts program in New Yor...
# 131   In a smog-choked dystopian Los Angeles, blade ...
# 132   A group of superheroes sets out to rid the wor...
# 133   In a futuristic society where an indestructibl...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8678 rows x 8 columns]

# %% [markdown]
# ***5. Tampilkan jumlah nilai dari semua attribute yang bernilai object (contoh : Jenis Kelamin, Agama).***

# %%
kolobjek = data.select_dtypes(include='object')
jumlah_kolom_ob = kolobjek.nunique()
pd.DataFrame({'Jumlah Kolom Objek ': jml_kol_objk})
# Out:
#              Jumlah Kolom Objek
# show_id                     8807
# type                           2
# title                       8807
# director                    4528
# cast                        7692
# country                      748
# date_added                  1767
# duration                     220
# listed_in                    514
# description                 8775
